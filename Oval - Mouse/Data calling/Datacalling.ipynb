_run_filtered_feature_bc_matrix_features.tsv.gz"
mget "Ind010-oviduct10_run_filtered_feature_bc_matrix_features.tsv.gz"
mget "Ind001-oviduct01_run_filtered_feature_bc_matrix_barcodes.tsv.gz"
mget "18mo_Ind002-oviduct02_run_raw_feature_bc_matrix_features.tsv.gz"
mget "Ind010-oviduct10_run_filtered_feature_bc_matrix_matrix.mtx.gz"
mget "Ind006-oviduct06_run_raw_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind006-uterus06_run_filtered_feature_bc_matrix_features.tsv.gz"
mget "Ind016-oviduct01_run_filtered_feature_bc_matrix_features.tsv.gz"
mget "Ind013-spleen01_run_raw_feature_bc_matrix_barcodes.tsv.gz"
mget "18mo_Ind003-spleen03_run_raw_feature_bc_matrix_matrix.mtx.gz"
mget "Ind015-oviduct01_run_filtered_feature_bc_matrix_features.tsv.gz"
mget "Ind001-cervix01_run_filtered_feature_bc_matrix_matrix.mtx.gz"
mget "Ind001-ovary01_run_filtered_feature_bc_matrix_features.tsv.gz"
mget "Ind016-spleen01_run_raw_feature_bc_matrix_barcodes.tsv.gz"
mget "D09-uterus01_run_filtered_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind006-uterus06_run_raw_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind009-ovary09_run_raw_feature_bc_matrix_matrix.mtx.gz"
mget "Ind016-ovary01_run_filtered_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind001-spleen01_run_raw_feature_bc_matrix_features.tsv.gz"
mget "Ind002-cervix02_run_filtered_feature_bc_matrix_features.tsv.gz"
mget "Ind012-uterus01_run_raw_feature_bc_matrix_matrix.mtx.gz"
mget "Ind007-ovary07_run_raw_feature_bc_matrix_matrix.mtx.gz"
mget "18mo_Ind005-ovary01_run_filtered_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind001-ovary01_run_filtered_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind008-spleen08_run_filtered_feature_bc_matrix_matrix.mtx.gz"
mget "Ind002-cervix02_run_raw_feature_bc_matrix_features.tsv.gz"
mget "Ind011-spleen11_run_filtered_feature_bc_matrix_matrix.mtx.gz"
mget "Ind003-cervix03_run_raw_feature_bc_matrix_matrix.mtx.gz"
mget "Ind002-spleen02_run_filtered_feature_bc_matrix_features.tsv.gz"
mget "Ind015-spleen01_run_raw_feature_bc_matrix_matrix.mtx.gz"
mget "Ind014-spleen01_run_raw_feature_bc_matrix_features.tsv.gz"
mget "Ind014-cervix01_run_raw_feature_bc_matrix_features.tsv.gz"
mget "Ind014-vagina01_run_raw_feature_bc_matrix_features.tsv.gz"
mget "18mo_Ind003-cervix03_run_raw_feature_bc_matrix_features.tsv.gz"
mget "D09-uterus01_run_raw_feature_bc_matrix_features.tsv.gz"
mget "Ind006-oviduct06_run_raw_feature_bc_matrix_features.tsv.gz"
mget "Ind003-oviduct03_run_filtered_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind001-spleen01_run_raw_feature_bc_matrix_matrix.mtx.gz"
mget "Ind010-cervix10_run_raw_feature_bc_matrix_matrix.mtx.gz"
mget "Ind011-ovary11_run_raw_feature_bc_matrix_features.tsv.gz"
mget "Ind013-ovary01_run_filtered_feature_bc_matrix_matrix.mtx.gz"
mget "Ind013-uterus01_run_filtered_feature_bc_matrix_matrix.mtx.gz"
mget "Ind015-spleen01_run_raw_feature_bc_matrix_features.tsv.gz"
mget "Ind014-ovary01_run_filtered_feature_bc_matrix_matrix.mtx.gz"
mget "Ind015-vagina01_run_raw_feature_bc_matrix_matrix.mtx.gz"
mget "Ind003-uterus03_run_raw_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind006-cervix06_run_raw_feature_bc_matrix_features.tsv.gz"
mget "Ind013-uterus01_run_raw_feature_bc_matrix_features.tsv.gz"
mget "Ind011-oviduct11_run_raw_feature_bc_matrix_barcodes.tsv.gz"
mget "D10-uterus01_run_raw_feature_bc_matrix_features.tsv.gz"
mget "Ind006-ovary06_run_raw_feature_bc_matrix_matrix.mtx.gz"
mget "Ind009-cervix09_run_filtered_feature_bc_matrix_features.tsv.gz"
mget "18mo_Ind002-spleen02_run_raw_feature_bc_matrix_matrix.mtx.gz"
mget "Ind011-cervix11_run_filtered_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind001-cervix01_run_filtered_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind002-vagina02_run_filtered_feature_bc_matrix_barcodes.tsv.gz"
mget "18mo_Ind003-cervix03_run_filtered_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind011-spleen11_run_raw_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind015-oviduct01_run_raw_feature_bc_matrix_features.tsv.gz"
mget "Ind016-vagina01_run_raw_feature_bc_matrix_features.tsv.gz"
mget "Ind001-uterus01_run_raw_feature_bc_matrix_features.tsv.gz"
mget "Ind009-uterus09_run_raw_feature_bc_matrix_features.tsv.gz"
mget "Ind011-uterus11_run_raw_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind003-oviduct03_run_raw_feature_bc_matrix_features.tsv.gz"
mget "Ind010-vagina10_run_raw_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind013-spleen01_run_filtered_feature_bc_matrix_features.tsv.gz"
mget "Ind006-oviduct06_run_filtered_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind009-ovary09_run_filtered_feature_bc_matrix_matrix.mtx.gz"
mget "Ind011-oviduct11_run_filtered_feature_bc_matrix_features.tsv.gz"
mget "Ind010-oviduct10_run_raw_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind009-spleen09_run_raw_feature_bc_matrix_features.tsv.gz"
mget "Ind011-ovary11_run_raw_feature_bc_matrix_matrix.mtx.gz"
mget "Ind007-cervix07_run_raw_feature_bc_matrix_features.tsv.gz"
mget "Ind008-spleen08_run_filtered_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind010-cervix10_run_raw_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind015-uterus01_run_filtered_feature_bc_matrix_barcodes.tsv.gz"
mget "18mo_Ind005-spleen01_run_raw_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind008-vagina08_run_raw_feature_bc_matrix_matrix.mtx.gz"
mget "Ind001-spleen01_run_filtered_feature_bc_matrix_barcodes.tsv.gz"
mget "18mo_Ind002-vagina02_run_filtered_feature_bc_matrix_matrix.mtx.gz"
mget "Ind011-uterus11_run_raw_feature_bc_matrix_matrix.mtx.gz"
mget "Ind007-ovary07_run_filtered_feature_bc_matrix_matrix.mtx.gz"
mget "Ind012-ovary01_run_filtered_feature_bc_matrix_features.tsv.gz"
mget "18mo_Ind002-cervix02_run_filtered_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind009-spleen09_run_filtered_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind010-vagina10_run_raw_feature_bc_matrix_features.tsv.gz"
mget "DC_Ind003-uterus01_run_filtered_feature_bc_matrix_matrix.mtx.gz"
mget "Ind015-vagina01_run_raw_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind014-cervix01_run_raw_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind009-oviduct09_run_raw_feature_bc_matrix_features.tsv.gz"
mget "Ind009-vagina09_run_filtered_feature_bc_matrix_barcodes.tsv.gz"
mget "D10-uterus01_run_raw_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind007-ovary07_run_filtered_feature_bc_matrix_barcodes.tsv.gz"
mget "18mo_Ind003-vagina03_run_raw_feature_bc_matrix_matrix.mtx.gz"
mget "Ind010_uterus10_run_raw_feature_bc_matrix_matrix.mtx.gz"
mget "18mo_Ind002-uterus02_run_raw_feature_bc_matrix_barcodes.tsv.gz"
mget "18mo_Ind002-vagina02_run_filtered_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind012-vagina01_run_filtered_feature_bc_matrix_matrix.mtx.gz"
mget "Ind013-oviduct01_run_raw_feature_bc_matrix_matrix.mtx.gz"
mget "Ind008-ovary08_run_raw_feature_bc_matrix_matrix.mtx.gz"
mget "Ind009-vagina09_run_filtered_feature_bc_matrix_features.tsv.gz"
mget "Ind008-vagina08_run_filtered_feature_bc_matrix_features.tsv.gz"
mget "Ind009-vagina09_run_raw_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind007-spleen07_run_raw_feature_bc_matrix_features.tsv.gz"
mget "Ind012-oviduct01_run_filtered_feature_bc_matrix_matrix.mtx.gz"
mget "Ind014-cervix01_run_filtered_feature_bc_matrix_matrix.mtx.gz"
mget "Ind009-oviduct09_run_filtered_feature_bc_matrix_features.tsv.gz"
mget "Ind002-ovary02_run_filtered_feature_bc_matrix_matrix.mtx.gz"
mget "Ind015-ovary01_run_raw_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind009-uterus09_run_filtered_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind010-cervix10_run_filtered_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind013-uterus01_run_raw_feature_bc_matrix_matrix.mtx.gz"
mget "Ind003-uterus03_run_filtered_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind009-uterus09_run_filtered_feature_bc_matrix_features.tsv.gz"
mget "18mo_Ind003-vagina03_run_raw_feature_bc_matrix_features.tsv.gz"
mget "Ind003-ovary03_run_filtered_feature_bc_matrix_matrix.mtx.gz"
mget "Ind003-cervix03_run_raw_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind015-oviduct01_run_filtered_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind011-ovary11_run_filtered_feature_bc_matrix_matrix.mtx.gz"
mget "Ind002-uterus02_run_filtered_feature_bc_matrix_barcodes.tsv.gz"
mget "18mo_Ind003-ovary03_run_raw_feature_bc_matrix_barcodes.tsv.gz"
mget "E-MTAB-11491.idf.txt"
mget "E-MTAB-11491.sdrf.txt"

""".strip()

lines = input_text.split('\n')

total_files = len(lines)
missing_files = 0

for line in lines:
    if '"' in line:
        filename = line.split('"')[1]
    else:
        continue

    full_path = os.path.join(base_dir, filename)
    if not os.path.exists(full_path):
        print(line)
        missing_files += 1

download_percent = (total_files - missing_files) / total_files * 100

print(f"\nDownload Percentage: {download_percent:.2f}% ({total_files - missing_files} / {total_files})")
# Out:
# Download Percentage: 100.00% (644 / 644)

# %%
import os

# 🔹 기준 경로
base_dir = '/home/NAS/kykim/Oval/E-MTAB-11491/'

# 🔹 다운로드 대상 목록 (mget 줄들만 넣으면 됨)
file_list_text = """
mget "Ind014-ovary01_run_filtered_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind014-ovary01_run_filtered_feature_bc_matrix_features.tsv.gz"
mget "Ind014-ovary01_run_filtered_feature_bc_matrix_matrix.mtx.gz"
mget "Ind013-oviduct01_run_filtered_feature_bc_matrix_barcodes.tsv.gz"
mget "Ind013-oviduct01_run_filtered_feature_bc_matrix_matrix.mtx.gz"
mget "Ind013-oviduct01_run_filtered_feature_bc_matrix_features.tsv.gz"
""".strip()

# 🔹 파싱
mget_lines = file_list_text.splitlines()
missing_mget_lines = []

for line in mget_lines:
    if '"' in line:
        filename = line.split('"')[1]
        filepath = os.path.join(base_dir, filename)
        if not os.path.exists(filepath):
            missing_mget_lines.append(line)

# 🔹 bash 스크립트 생성
print("#!/bin/bash")
print("# Run this file in bash with this command:  ./download_missing_files.sh")
print("cd /home/NAS/kykim/Oval/E-MTAB-11491/")
print("HOST=ftp.ebi.ac.uk")
print("USER=anonymous")
print("ftp -pinv $HOST <<EOF")
print("user $USER")
print("cd biostudies/fire/E-MTAB-/491/E-MTAB-11491/Files")
print("binary")

for line in missing_mget_lines:
    print(line)

print("disconnect")
print("bye")
print("EOF")
# Out:
# #!/bin/bash
# # Run this file in bash with this command:  ./download_missing_files.sh
# cd /home/NAS/kykim/Oval/E-MTAB-11491/
# HOST=ftp.ebi.ac.uk
# USER=anonymous
# ftp -pinv $HOST <<EOF
# user $USER
# cd biostudies/fire/E-MTAB-/491/E-MTAB-11491/Files
# binary
# disconnect
# bye
# EOF

# %% [markdown]
# # 10X Visium

# %%
import os
import sys

base_dir = '/home/NAS/kykim/Oval/E-MTAB-12105/'

# 다운로드 진행 안 된 파일 리스트 check
input_text = """
mget "V12N14-362_C1_scalefactors_json.json"
mget "V12M07-027_C1_tissue_positions_list.csv"
mget "V12N14-364_A1_tissue_positions_list.csv"
mget "V19D02-108_D1_tissue_positions_list.csv"
mget "V19D02-108_B1_tissue_positions_list.csv"
mget "V12N14-364_B1_tissue_positions_list.csv"
mget "V12N14-362_D1_tissue_positions_list.csv"
mget "V12N14-362-C1.json"
mget "V12N14-362_B1_filtered_feature_bc_matrix.h5"
mget "V12N14-363-C1.json"
mget "V19D02-108-B1.json"
mget "V11M25-311-B1.json"
mget "V11M25-311_B1_filtered_feature_bc_matrix.h5"
mget "V11M25-312_A1_scalefactors_json.json"
mget "V11M25-312_B1_tissue_positions_list.csv"
mget "V12N14-363_A1_filtered_feature_bc_matrix.h5"
mget "V11M25-312-A1.json"
mget "V12N14-364_B1_filtered_feature_bc_matrix.h5"
mget "V12N14-362_B1_scalefactors_json.json"
mget "V11M25-312_D1_filtered_feature_bc_matrix.h5"
mget "V19D02-108_B1_scalefactors_json.json"
mget "V11M25-373_C1_tissue_positions_list.csv"
mget "V12N14-362_D1_scalefactors_json.json"
mget "V12M07-027_C1_scalefactors_json.json"
mget "V12M07-027_B1_tissue_positions_list.csv"
mget "V12N14-363-A1.json"
mget "V19D02-108_A1_tissue_positions_list.csv"
mget "V11M25-373_D1_filtered_feature_bc_matrix.h5"
mget "V12N14-363_B1_scalefactors_json.json"
mget "V11M25-311_B1_tissue_positions_list.csv"
mget "V12M07-027_C1_filtered_feature_bc_matrix.h5"
mget "V12N14-363_C1_tissue_positions_list.csv"
mget "V12M07-027_D1_tissue_positions_list.csv"
mget "V12N14-363_A1_scalefactors_json.json"
mget "V12N14-363_D1_filtered_feature_bc_matrix.h5"
mget "V11M25-312_D1_tissue_positions_list.csv"
mget "V12N14-364_A1_filtered_feature_bc_matrix.h5"
mget "V19D02-108_D1_scalefactors_json.json"
mget "V19D02-108_A1_filtered_feature_bc_matrix.h5"
mget "V11M25-312-B1.json"
mget "V12N14-362_C1_filtered_feature_bc_matrix.h5"
mget "V11M25-312_A1_tissue_positions_list.csv"
mget "V12N14-364-D1.json"
mget "V11M25-312_C1_tissue_positions_list.csv"
mget "V19D02-108_A1_scalefactors_json.json"
mget "V11M25-312_B1_scalefactors_json.json"
mget "V11M25-312-D1.json"
mget "V12N14-362_C1_tissue_positions_list.csv"
mget "V11M25-312-C1.json"
mget "V12N14-364-A1.json"
mget "V12N14-363_C1_scalefactors_json.json"
mget "V19D02-108_D1_filtered_feature_bc_matrix.h5"
mget "V12M07-027
mget "V12N14-362_B1_tissue_hires_image.png"
mget "V12N14-362_C1_tissue_hires_image.png"
mget "V12N14-362_D1_tissue_hires_image.png"
mget "E-MTAB-12105.idf.txt"
mget "E-MTAB-12105.sdrf.txt"
""".strip()

lines = input_text.split('\n')

total_files = len(lines)
missing_files = 0

for line in lines:
    if '"' in line:
        filename = line.split('"')[1]
    else:
        continue

    full_path = os.path.join(base_dir, filename)
    if not os.path.exists(full_path):
        print(line)
        missing_files += 1

download_percent = (total_files - missing_files) / total_files * 100

print(f"\nDownload Percentage: {download_percent:.2f}% ({total_files - missing_files} / {total_files})")
# Out:
# mget "V12N14-362_C1_scalefactors_json.json"
# mget "V12M07-027_C1_tissue_positions_list.csv"
# mget "V12N14-364_A1_tissue_positions_list.csv"
# mget "V19D02-108_D1_tissue_positions_list.csv"
# mget "V19D02-108_B1_tissue_positions_list.csv"
# mget "V12N14-364_B1_tissue_positions_list.csv"
# mget "V12N14-362_D1_tissue_positions_list.csv"
# mget "V12N14-362-C1.json"
# mget "V12N14-362_B1_filtered_feature_bc_matrix.h5"
# mget "V12N14-363-C1.json"
# mget "V19D02-108-B1.json"
# mget "V11M25-311-B1.json"
# mget "V11M25-311_B1_filtered_feature_bc_matrix.h5"
# mget "V11M25-312_A1_scalefactors_json.json"
# mget "V11M25-312_B1_tissue_positions_list.csv"
# mget "V12N14-363_A1_filtered_feature_bc_matrix.h5"
# mget "V11M25-312-A1.json"
# mget "V12N14-364_B1_filtered_feature_bc_matrix.h5"
# mget "V12N14-362_B1_scalefactors_json.json"
# mget "V11M25-312_D1_filtered_feature_bc_matrix.h5"
# mget "V19D02-108_B1_scalefactors_json.json"
# mget "V11M25-373_C1_tissue_positions_list.csv"
# ...

# %%
import os

# 🔹 기준 경로
base_dir = '/home/NAS/kykim/Oval/E-MTAB-12105/'

# 🔹 다운로드 대상 목록 (mget 줄들만 넣으면 됨)
file_list_text = """
mget "V12N14-362_C1_scalefactors_json.json"
mget "V12M07-027_C1_tissue_positions_list.csv"
mget "V12N14-364_A1_tissue_positions_list.csv"
mget "V19D02-108_D1_tissue_positions_list.csv"
mget "V19D02-108_B1_tissue_positions_list.csv"
mget "V12N14-364_B1_tissue_positions_list.csv"
mget "V12N14-362_D1_tissue_positions_list.csv"
mget "V12N14-362-C1.json"
mget "V12N14-362_B1_filtered_feature_bc_matrix.h5"
mget "V12N14-363-C1.json"
mget "V19D02-108-B1.json"
mget "V11M25-311-B1.json"
mget "V11M25-311_B1_filtered_feature_bc_matrix.h5"
mget "V11M25-312_A1_scalefactors_json.json"
mget "V11M25-312_B1_tissue_positions_list.csv"
mget "V12N14-363_A1_filtered_feature_bc_matrix.h5"
mget "V11M25-312-A1.json"
mget "V12N14-364_B1_filtered_feature_bc_matrix.h5"
mget "V12N14-362_B1_scalefactors_json.json"
mget "V11M25-312_D1_filtered_feature_bc_matrix.h5"
mget "V19D02-108_B1_scalefactors_json.json"
mget "V11M25-373_C1_tissue_positions_list.csv"
mget "V12N14-362_D1_scalefactors_json.json"
mget "V12M07-027_C1_scalefactors_json.json"
mget "V12M07-027_B1_tissue_positions_list.csv"
mget "V12N14-363-A1.json"
mget "V19D02-108_A1_tissue_positions_list.csv"
mget "V11M25-373_D1_filtered_feature_bc_matrix.h5"
mget "V12N14-363_B1_scalefactors_json.json"
mget "V11M25-311_B1_tissue_positions_list.csv"
mget "V12M07-027_C1_filtered_feature_bc_matrix.h5"
mget "V12N14-363_C1_tissue_positions_list.csv"
mget "V12M07-027_D1_tissue_positions_list.csv"
mget "V12N14-363_A1_scalefactors_json.json"
mget "V12N14-363_D1_filtered_feature_bc_matrix.h5"
mget "V11M25-312_D1_tissue_positions_list.csv"
mget "V12N14-364_A1_filtered_feature_bc_matrix.h5"
mget "V19D02-108_D1_scalefactors_json.json"
mget "V19D02-108_A1_filtered_feature_bc_matrix.h5"
mget "V11M25-312-B1.json"
mget "V12N14-362_C1_filtered_feature_bc_matrix.h5"
mget "V11M25-312_A1_tissue_positions_list.csv"
mget "V12N14-364-D1.json"
mget "V11M25-312_C1_tissue_positions_list.csv"
mget "V19D02-108_A1_scalefactors_json.json"
mget "V11M25-312_B1_scalefactors_json.json"
mget "V11M25-312-D1.json"
mget "V12N14-362_C1_tissue_positions_list.csv"
mget "V11M25-312-C1.json"
mget "V12N14-364-A1.json"
mget "V12N14-363_C1_scalefactors_json.json"
mget "V19D02-108_D1_filtered_feature_bc_matrix.h5"
mget "V12M07-027_A1_tissue_positions_list.csv"
mget "V12N14-363_B1_tissue_positions_list.csv"
mget "V12M07-027-A1.json"
mget "V12M07-027-B1.json"
mget "V12M07-027_A1_scalefactors_json.json"
mget "V11M25-312_D1_scalefactors_json.json"
mget "V19D02-108_C1_filtered_feature_bc_matrix.h5"
mget "V12M07-027_A1_filtered_feature_bc_matrix.h5"
mget "V12M07-027_D1_filtered_feature_bc_matrix.h5"
mget "V12M07-027_D1_scalefactors_json.json"
mget "V12N14-363-D1.json"
mget "V12N14-364_B1_scalefactors_json.json"
mget "V12N14-362_A1_filtered_feature_bc_matrix.h5"
mget "V11M25-373_D1_scalefactors_json.json"
mget "V19D02-108-D1.json"
mget "V19D02-108_B1_filtered_feature_bc_matrix.h5"
mget "V12N14-363_B1_filtered_feature_bc_matrix.h5"
mget "V12M07-027_B1_scalefactors_json.json"
mget "V12N14-363_D1_scalefactors_json.json"
mget "V11M25-312_A1_filtered_feature_bc_matrix.h5"
mget "V12N14-363_C1_filtered_feature_bc_matrix.h5"
mget "V12N14-362-D1.json"
mget "V11M25-373-D1.json"
mget "V12N14-364-C1.json"
mget "V12N14-364_D1_tissue_positions_list.csv"
mget "V19D02-108-C1.json"
mget "V19D02-108-A1.json"
mget "V12N14-363_A1_tissue_positions_list.csv"
mget "V12N14-364_D1_scalefactors_json.json"
mget "V12N14-364_A1_scalefactors_json.json"
mget "V12N14-364_C1_scalefactors_json.json"
mget "V12N14-362_A1_scalefactors_json.json"
mget "V12N14-364-B1.json"
mget "V12N14-363-B1.json"
mget "V19D02-108_C1_scalefactors_json.json"
mget "V12N14-364_C1_filtered_feature_bc_matrix.h5"
mget "V11M25-373_D1_tissue_positions_list.csv"
mget "V11M25-312_B1_filtered_feature_bc_matrix.h5"
mget "V12M07-027-D1.json"
mget "V11M25-312_C1_filtered_feature_bc_matrix.h5"
mget "V19D02-108_C1_tissue_positions_list.csv"
mget "V12N14-364_C1_tissue_positions_list.csv"
mget "V12N14-362-B1.json"
mget "V12N14-362_A1_tissue_positions_list.csv"
mget "V12N14-364_D1_filtered_feature_bc_matrix.h5"
mget "V12N14-362-A1.json"
mget "V12M07-027-C1.json"
mget "V11M25-373_C1_filtered_feature_bc_matrix.h5"
mget "V11M25-312_C1_scalefactors_json.json"
mget "V12N14-363_D1_tissue_positions_list.csv"
mget "V12N14-362_D1_filtered_feature_bc_matrix.h5"
mget "V12M07-027_B1_filtered_feature_bc_matrix.h5"
mget "V12N14-362_B1_tissue_positions_list.csv"
mget "V11M25-311_B1_scalefactors_json.json"
mget "V11M25-373_C1_scalefactors_json.json"
mget "V11M25-373-C1.json"
mget "V11M25-312_A1_tissue_hires_image.png"
mget "V11M25-312_B1_tissue_hires_image.png"
mget "V11M25-312_C1_tissue_hires_image.png"
mget "V11M25-312_D1_tissue_hires_image.png"
mget "V11M25-311_B1_tissue_hires_image.png"
mget "V12N14-364_A1_tissue_hires_image.png"
mget "V12N14-364_B1_tissue_hires_image.png"
mget "V12N14-364_C1_tissue_hires_image.png"
mget "V12N14-364_D1_tissue_hires_image.png"
mget "V12N14-363_A1_tissue_hires_image.png"
mget "V12N14-363_B1_tissue_hires_image.png"
mget "V19D02-108_B1_tissue_hires_image.png"
mget "V19D02-108_A1_tissue_hires_image.png"
mget "V11M25-373_C1_tissue_hires_image.png"
mget "V11M25-373_D1_tissue_hires_image.png"
mget "V19D02-108_C1_tissue_hires_image.png"
mget "V19D02-108_D1_tissue_hires_image.png"
mget "V12M07-027_B1_tissue_hires_image.png"
mget "V12M07-027_A1_tissue_hires_image.png"
mget "V12M07-027_C1_tissue_hires_image.png"
mget "V12M07-027_D1_tissue_hires_image.png"
mget "V12N14-363_C1_tissue_hires_image.png"
mget "V12N14-363_D1_tissue_hires_image.png"
mget "V12N14-362_A1_tissue_hires_image.png"
mget "V12N14-362_B1_tissue_hires_image.png"
mget "V12N14-362_C1_tissue_hires_image.png"
mget "V12N14-362_D1_tissue_hires_image.png"
mget "E-MTAB-12105.idf.txt"
mget "E-MTAB-12105.sdrf.txt"
""".strip()

# 🔹 파싱
mget_lines = file_list_text.splitlines()
missing_mget_lines = []

for line in mget_lines:
    if '"' in line:
        filename = line.split('"')[1]
        filepath = os.path.join(base_dir, filename)
        if not os.path.exists(filepath):
            missing_mget_lines.append(line)

# 🔹 bash 스크립트 생성
print("#!/bin/bash")
print("# Run this file in bash with this command:  ./filename")
print("cd /home/NAS/kykim/Oval/E-MTAB-12105/")
print("HOST=ftp.ebi.ac.uk")
print("USER=anonymous")
print("ftp -pinv $HOST <<EOF")
print("user $USER")
print("cd biostudies/fire/E-MTAB-/105/E-MTAB-12105/Files")
print("binary")

for line in missing_mget_lines:
    print(line)

print("disconnect")
print("bye")
print("EOF")
# Out:
# #!/bin/bash
# # Run this file in bash with this command:  ./filename
# cd /home/NAS/kykim/Oval/E-MTAB-12105/
# HOST=ftp.ebi.ac.uk
# USER=anonymous
# ftp -pinv $HOST <<EOF
# user $USER
# cd biostudies/fire/E-MTAB-/105/E-MTAB-12105/Files
# binary
# mget "V12N14-362_C1_scalefactors_json.json"
# mget "V12M07-027_C1_tissue_positions_list.csv"
# mget "V12N14-364_A1_tissue_positions_list.csv"
# mget "V19D02-108_D1_tissue_positions_list.csv"
# mget "V19D02-108_B1_tissue_positions_list.csv"
# mget "V12N14-364_B1_tissue_positions_list.csv"
# mget "V12N14-362_D1_tissue_positions_list.csv"
# mget "V12N14-362-C1.json"
# mget "V12N14-362_B1_filtered_feature_bc_matrix.h5"
# mget "V12N14-363-C1.json"
# mget "V19D02-108-B1.json"
# mget "V11M25-311-B1.json"
# mget "V11M25-311_B1_filtered_feature_bc_matrix.h5"
# mget "V11M25-312_A1_scalefactors_json.json"
# mget "V11M25-312_B1_tissue_positions_list.csv"
# mget "V12N14-363_A1_filtered_feature_bc_matrix.h5"
# mget "V11M25-312-A1.json"
# ...
